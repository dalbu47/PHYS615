# %% [markdown]
# # $\text{PHYS 605 Homework 4 Problem 4a}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint


x = np.linspace(0,np.pi*4,10000)
w = 1
R = 1
g = 9.8

U = -0.5*(np.sin(x))**2+g*(1-np.cos(x))
plt.plot(x,U)
